# %% [markdown]
# # Machine Learning - UFRJ 2022.2
# ## Regressão Linear Múltipla
#
# #### Feito por Rafael da Silva Fernandes, DRE: 117196229

# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

from itertools import combinations

# %% [markdown]
# ## Lendo e analisando dataset

# %%
df = pd.read_csv("data-t1.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %% [markdown]
# Dado que a coluna "diagnosis" é do tipo object, precisamos convertê-la para inteiro para sermos capazes de realizar a regressão linear. Na célula abaixo, trocamos todos os valores de "M" (Maligno) para 1, e todos os valores de "B" (Benigno) para 0 - na verdade, todos os valores diferentes de "M" serão iguais à 0, mas como há apenas "B" como diferente, podemos dizer que todos os que não são "M" serão iguais à 0.
#
# > Referência: https://www.geeksforgeeks.org/how-to-replace-values-in-column-based-on-condition-in-pandas/

# %%
df["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df["diagnosis"] = np.where(df["diagnosis"] == "M", 1, 0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(2)
# memory usage: 146.8 KB

# %% [markdown]
# Podemos observar pelos resultados acima que todas as colunas estão completamente preenchidas, com exceção da última ("Unnamed: 32") que está completamente vazia. Por essa razão, a removemos do dataset por meio da célula abaixo.

# %%
df.drop(columns = ["Unnamed: 32"], inplace = True)
df.shape
# Out:
# (569, 32)

# %% [markdown]
# Para garantir que todas as linhas do dataset são únicas, utilizamos a célula abaixo para remover qualquer duplicata existente. O dataset continua com suas 569 linhas e 32 colunas, portanto podemos afirmar que todas as linhas já eram únicas.

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (569, 32)

# %% [markdown]
# Por via das dúvidas, removemos todos os valores NaN ou Infinito que possam haver no dataset. Dado que ele continua com 569 linhas e 32 colunas, não havia tais valores.
#
# > Referência: https://stackoverflow.com/questions/45745085/python-pandas-how-to-remove-nan-and-inf-values

# %%
df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]
df.shape
# Out:
# (569, 32)

# %% [markdown]
# ## Inicializando modelo de Regressão Linear Múltipla
#
# > Referência: https://datatofish.com/multiple-linear-regression-python/

# %% [markdown]
# Apesar do primeiro passo para saber se aplicamos ou não regressão linear ser plotar as combinações de colunas, dado que temos 435 combinações esse passo foi pulado - fora o fato do exercício ser sobre regressão linear por si só.

# %%
column_combination = list(combinations(df.columns[2:].tolist(), 2))
len(column_combination)
# Out:
# 435

# %%
# Todos os valores do dataset, excluindo as tabelas "id" e "diagnosis"
x = df.iloc[:, 2:]
x = sm.add_constant(x) 

# Variável dependente
y = df["diagnosis"]

linear_reg = sm.OLS(y, x).fit()
summary = linear_reg.summary()
summary
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              diagnosis   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     61.53
# Date:                Mon, 19 Sep 2022   Prob (F-statistic):          6.05e-153
# Time:                        12:00:44   Log-Likelihood:                 29.650
# No. Observations:                 569   AIC:                             2.699
# Df Residuals:                     538   BIC:                             137.4
# Df Model:                          30
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -2.0218      0.428     -4.724      0.000      -2.863      -1.181
# radius_mean                -0.2178      0.174     -1.255      0.210      -0.559       0.123
# texture_mean                0.0045      0.008      0.572      0.567      -0.011       0.020
# perimeter_mean              0.0237      0.025      0.946      0.345      -0.026       0.073
# area_mean                   0.0003      0.001      0.605      0.545      -0.001       0.001
# smoothness_mean             0.0847      2.017      0.042      0.967      -3.878       4.047
# compactness_mean           -4.2220      1.334     -3.166      0.002      -6.842      -1.602
# concavity_mean              1.3980      1.046      1.337      0.182      -0.656       3.452
# concave points_mean         2.1418      1.979      1.082      0.280      -1.746       6.030
# symmetry_mean               0.1027      0.743      0.138      0.890      -1.356       1.562
# fractal_dimension_mean      0.0333      5.572      0.006      0.995     -10.913      10.979
# radius_se                   0.4350      0.310      1.401      0.162      -0.175       1.045
# texture_se                 -0.0068      0.037     -0.183      0.855      -0.079       0.066
# perimeter_se               -0.0225      0.041     -0.548      0.584      -0.103       0.058
# area_se                    -0.0009      0.001     -0.660      0.509      -0.004       0.002
# smoothness_se              15.8543      6.625      2.393      0.017       2.841      28.868
# compactness_se              0.0649      2.169      0.030      0.976      -4.197       4.327
# concavity_se               -3.5655      1.301     -2.741      0.006      -6.121      -1.010
# concave points_se          10.5680      5.452      1.938      0.053      -0.142      21.278
# symmetry_se                 1.6973      2.728      0.622      0.534      -3.661       7.055
# fractal_dimension_se       -7.1464     11.676     -0.612      0.541     -30.083      15.791
# radius_worst                0.1952      0.058      3.367      0.001       0.081       0.309
# texture_worst               0.0072      0.007      1.030      0.303      -0.006       0.021
# perimeter_worst            -0.0024      0.006     -0.410      0.682      -0.014       0.009
# area_worst                 -0.0010      0.000     -3.163      0.002      -0.002      -0.000
# smoothness_worst            0.5429      1.435      0.378      0.705      -2.275       3.361
# compactness_worst           0.0672      0.383      0.175      0.861      -0.685       0.820
# concavity_worst             0.3812      0.269      1.419      0.156      -0.146       0.909
# concave points_worst        0.4643      0.914      0.508      0.612      -1.332       2.260
# symmetry_worst              0.5568      0.494      1.126      0.260      -0.414       1.528
# fractal_dimension_worst     4.3035      2.383      1.806      0.072      -0.378       8.985
# ==============================================================================
# Omnibus:                       32.654   Durbin-Watson:                   1.794
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.690
# Skew:                           0.603   Prob(JB):                     1.08e-08
# Kurtosis:                       3.302   Cond. No.                     1.54e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Com o intuito de facilitar a visualização e retirada de informações, colocamos os dados retornados acima em um DataFrame.
#
# > Referência: https://stackoverflow.com/questions/51734180/converting-statsmodels-summary-object-to-pandas-dataframe

# %%
summary_as_html = summary.tables[1].as_html()
df_summary = pd.read_html(summary_as_html, header = 0, index_col = 0)[0]
df_summary = df_summary.iloc[1: , :]
df_summary
# Out:
#                             coef  std err      t  P>|t|  [0.025  0.975]
# radius_mean              -0.2178    0.174 -1.255  0.210  -0.559   0.123
# texture_mean              0.0045    0.008  0.572  0.567  -0.011   0.020
# perimeter_mean            0.0237    0.025  0.946  0.345  -0.026   0.073
# area_mean                 0.0003    0.001  0.605  0.545  -0.001   0.001
# smoothness_mean           0.0847    2.017  0.042  0.967  -3.878   4.047
# compactness_mean         -4.2220    1.334 -3.166  0.002  -6.842  -1.602
# concavity_mean            1.3980    1.046  1.337  0.182  -0.656   3.452
# concave points_mean       2.1418    1.979  1.082  0.280  -1.746   6.030
# symmetry_mean             0.1027    0.743  0.138  0.890  -1.356   1.562
# fractal_dimension_mean    0.0333    5.572  0.006  0.995 -10.913  10.979
# radius_se                 0.4350    0.310  1.401  0.162  -0.175   1.045
# texture_se               -0.0068    0.037 -0.183  0.855  -0.079   0.066
# perimeter_se             -0.0225    0.041 -0.548  0.584  -0.103   0.058
# area_se                  -0.0009    0.001 -0.660  0.509  -0.004   0.002
# smoothness_se            15.8543    6.625  2.393  0.017   2.841  28.868
# compactness_se            0.0649    2.169  0.030  0.976  -4.197   4.327
# concavity_se             -3.5655    1.301 -2.741  0.006  -6.121  -1.010
# concave points_se        10.5680    5.452  1.938  0.053  -0.142  21.278
# symmetry_se               1.6973    2.728  0.622  0.534  -3.661   7.055
# fractal_dimension_se     -7.1464   11.676 -0.612  0.541 -30.083  15.791
# radius_worst              0.1952    0.058  3.367  0.001   0.081   0.309
# texture_worst             0.0072    0.007  1.030  0.303  -0.006   0.021
# perimeter_worst          -0.0024    0.006 -0.410  0.682  -0.014   0.009
# area_worst               -0.0010    0.000 -3.163  0.002  -0.002  -0.000
# smoothness_worst          0.5429    1.435  0.378  0.705  -2.275   3.361
# compactness_worst         0.0672    0.383  0.175  0.861  -0.685   0.820
# concavity_worst           0.3812    0.269  1.419  0.156  -0.146   0.909
# concave points_worst      0.4643    0.914  0.508  0.612  -1.332   2.260
# symmetry_worst            0.5568    0.494  1.126  0.260  -0.414   1.528
# fractal_dimension_worst   4.3035    2.383  1.806  0.072  -0.378   8.985

# %% [markdown]
# Para descobrir quais as variáveis que influenciam no valor da coluna "diagnosis" em Maligno ou Benigno, comparamos os valores da coluna P>|t| com um alpha de nossa escolha. Utilizamos o valor padrão, que é igual à 0.05.

# %%
important_columns = df_summary.loc[df_summary["P>|t|"] < 0.05].index.tolist()
important_columns
# Out:
# ['compactness_mean',
#  'smoothness_se',
#  'concavity_se',
#  'radius_worst',
#  'area_worst']

# %% [markdown]
# ## Visualizando resultados

# %% [markdown]
# Inicializamos plotando a matriz de correlação do Matplotlib.

# %%
plt.matshow(df.iloc[:, 1:].corr())

# %% [markdown]
# Para uma melhor visualização, plotamos a matriz de correlação do Pandas.

# %%
correlation = df.iloc[:, 1:].corr()
correlation.style.background_gradient(cmap = "coolwarm")
# Out:
# <style type="text/css">
# #T_fedc4_row0_col0, #T_fedc4_row1_col1, #T_fedc4_row1_col3, #T_fedc4_row2_col2, #T_fedc4_row3_col1, #T_fedc4_row3_col3, #T_fedc4_row4_col4, #T_fedc4_row5_col5, #T_fedc4_row6_col6, #T_fedc4_row7_col7, #T_fedc4_row8_col8, #T_fedc4_row9_col9, #T_fedc4_row10_col10, #T_fedc4_row11_col11, #T_fedc4_row12_col12, #T_fedc4_row13_col13, #T_fedc4_row14_col14, #T_fedc4_row15_col15, #T_fedc4_row16_col16, #T_fedc4_row17_col17, #T_fedc4_row18_col18, #T_fedc4_row19_col19, #T_fedc4_row20_col20, #T_fedc4_row21_col21, #T_fedc4_row22_col22, #T_fedc4_row23_col23, #T_fedc4_row24_col24, #T_fedc4_row25_col25, #T_fedc4_row26_col26, #T_fedc4_row27_col27, #T_fedc4_row28_col28, #T_fedc4_row29_col29, #T_fedc4_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col1, #T_fedc4_row0_col3, #T_fedc4_row3_col28, #T_fedc4_row23_col0, #T_fedc4_row28_col24 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col2, #T_fedc4_row2_col12, #T_fedc4_row13_col27, #T_fedc4_row18_col15 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_fedc4_row0_col4, #T_fedc4_row0_col8, #T_fedc4_row1_col28, #T_fedc4_row11_col21, #T_fedc4_row11_col23, #T_fedc4_row13_col23, #T_fedc4_row20_col16 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col5, #T_fedc4_row1_col2, #T_fedc4_row5_col3, #T_fedc4_row5_col21, #T_fedc4_row5_col23, #T_fedc4_row9_col0, #T_fedc4_row25_col23, #T_fedc4_row28_col10 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_fedc4_row0_col6, #T_fedc4_row14_col0, #T_fedc4_row17_col10, #T_fedc4_row28_col14 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_fedc4_row0_col7, #T_fedc4_row6_col10 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_fedc4_row0_col9, #T_fedc4_row2_col8, #T_fedc4_row10_col18, #T_fedc4_row16_col25, #T_fedc4_row20_col9, #T_fedc4_row22_col25, #T_fedc4_row24_col18, #T_fedc4_row25_col22 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_fedc4_row0_col10, #T_fedc4_row9_col12, #T_fedc4_row20_col11, #T_fedc4_row20_col25 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col11, #T_fedc4_row9_col5, #T_fedc4_row23_col26, #T_fedc4_row26_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_fedc4_row0_col12, #T_fedc4_row0_col19, #T_fedc4_row29_col17 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col13, #T_fedc4_row3_col6, #T_fedc4_row7_col30, #T_fedc4_row10_col25, #T_fedc4_row16_col28, #T_fedc4_row18_col13, #T_fedc4_row28_col13 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_fedc4_row0_col14, #T_fedc4_row9_col6, #T_fedc4_row13_col0, #T_fedc4_row14_col7, #T_fedc4_row27_col29 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_fedc4_row0_col15, #T_fedc4_row20_col0, #T_fedc4_row21_col30 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col16, #T_fedc4_row5_col12, #T_fedc4_row20_col21 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col17, #T_fedc4_row12_col4, #T_fedc4_row14_col10, #T_fedc4_row20_col24, #T_fedc4_row29_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col18, #T_fedc4_row0_col30, #T_fedc4_row3_col22, #T_fedc4_row7_col2, #T_fedc4_row9_col3, #T_fedc4_row23_col29, #T_fedc4_row30_col8 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_fedc4_row0_col20, #T_fedc4_row15_col13, #T_fedc4_row24_col9 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col21, #T_fedc4_row0_col23, #T_fedc4_row8_col6, #T_fedc4_row26_col28, #T_fedc4_row30_col10 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col22, #T_fedc4_row7_col10, #T_fedc4_row29_col10 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_fedc4_row0_col24, #T_fedc4_row13_col24, #T_fedc4_row28_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col25, #T_fedc4_row1_col26, #T_fedc4_row5_col29, #T_fedc4_row7_col9, #T_fedc4_row9_col30, #T_fedc4_row16_col15, #T_fedc4_row16_col19, #T_fedc4_row17_col30, #T_fedc4_row18_col14, #T_fedc4_row22_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_fedc4_row0_col26, #T_fedc4_row18_col20, #T_fedc4_row26_col16 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_fedc4_row0_col27, #T_fedc4_row3_col13, #T_fedc4_row5_col10, #T_fedc4_row14_col8, #T_fedc4_row27_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_fedc4_row0_col28 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_fedc4_row0_col29, #T_fedc4_row1_col6, #T_fedc4_row2_col21, #T_fedc4_row5_col7, #T_fedc4_row20_col6 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_fedc4_row1_col0, #T_fedc4_row18_col17, #T_fedc4_row27_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_fedc4_row1_col4, #T_fedc4_row3_col4, #T_fedc4_row4_col1, #T_fedc4_row4_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col5, #T_fedc4_row12_col13, #T_fedc4_row13_col25, #T_fedc4_row14_col17 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col7, #T_fedc4_row6_col3, #T_fedc4_row7_col14, #T_fedc4_row24_col7 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_fedc4_row1_col8, #T_fedc4_row4_col8, #T_fedc4_row4_col14, #T_fedc4_row5_col25, #T_fedc4_row26_col30, #T_fedc4_row28_col3, #T_fedc4_row28_col26 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col9, #T_fedc4_row2_col18 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col10, #T_fedc4_row1_col20, #T_fedc4_row2_col5, #T_fedc4_row2_col9, #T_fedc4_row10_col1, #T_fedc4_row10_col2, #T_fedc4_row10_col3, #T_fedc4_row10_col4, #T_fedc4_row10_col11, #T_fedc4_row10_col13, #T_fedc4_row10_col14, #T_fedc4_row10_col21, #T_fedc4_row10_col24, #T_fedc4_row12_col6, #T_fedc4_row12_col7, #T_fedc4_row12_col8, #T_fedc4_row12_col25, #T_fedc4_row12_col26, #T_fedc4_row12_col27, #T_fedc4_row12_col28, #T_fedc4_row12_col29, #T_fedc4_row12_col30, #T_fedc4_row15_col0, #T_fedc4_row15_col22, #T_fedc4_row15_col23, #T_fedc4_row19_col22, #T_fedc4_row21_col15, #T_fedc4_row21_col19, #T_fedc4_row22_col16, #T_fedc4_row22_col17, #T_fedc4_row22_col18, #T_fedc4_row29_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col11, #T_fedc4_row29_col9 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_fedc4_row1_col12 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col13, #T_fedc4_row6_col23, #T_fedc4_row16_col27, #T_fedc4_row21_col7, #T_fedc4_row27_col21 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_fedc4_row1_col14, #T_fedc4_row7_col4, #T_fedc4_row11_col1, #T_fedc4_row11_col3, #T_fedc4_row13_col3 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_fedc4_row1_col15, #T_fedc4_row15_col8, #T_fedc4_row21_col20, #T_fedc4_row28_col12 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col16, #T_fedc4_row21_col16, #T_fedc4_row29_col13, #T_fedc4_row30_col12 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col17, #T_fedc4_row5_col22, #T_fedc4_row12_col16, #T_fedc4_row12_col17, #T_fedc4_row25_col19, #T_fedc4_row28_col15 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col18, #T_fedc4_row6_col19, #T_fedc4_row11_col5, #T_fedc4_row13_col16, #T_fedc4_row16_col12, #T_fedc4_row18_col12, #T_fedc4_row22_col29, #T_fedc4_row25_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_fedc4_row1_col19, #T_fedc4_row3_col15, #T_fedc4_row4_col10, #T_fedc4_row4_col20, #T_fedc4_row22_col9, #T_fedc4_row23_col12, #T_fedc4_row23_col19 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col21, #T_fedc4_row3_col21, #T_fedc4_row3_col23, #T_fedc4_row13_col11, #T_fedc4_row21_col3, #T_fedc4_row23_col1, #T_fedc4_row23_col3 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col22, #T_fedc4_row2_col27, #T_fedc4_row11_col26, #T_fedc4_row14_col26, #T_fedc4_row15_col5, #T_fedc4_row16_col14, #T_fedc4_row18_col9, #T_fedc4_row28_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_fedc4_row1_col23, #T_fedc4_row4_col21, #T_fedc4_row11_col13, #T_fedc4_row21_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_fedc4_row1_col24, #T_fedc4_row3_col24, #T_fedc4_row14_

# %% [markdown]
# Por fim, fazemos uma combinação 2 a 2 de todas as colunas importantes e plotamos a regressão linear entre elas, diferenciando a cor para os valores da coluna diagnosis.

# %%
important_column_combination = list(combinations(important_columns, 2))
important_column_combination
# Out:
# [('compactness_mean', 'smoothness_se'),
#  ('compactness_mean', 'concavity_se'),
#  ('compactness_mean', 'radius_worst'),
#  ('compactness_mean', 'area_worst'),
#  ('smoothness_se', 'concavity_se'),
#  ('smoothness_se', 'radius_worst'),
#  ('smoothness_se', 'area_worst'),
#  ('concavity_se', 'radius_worst'),
#  ('concavity_se', 'area_worst'),
#  ('radius_worst', 'area_worst')]

# %%
for combination in important_column_combination:

    x_axis = combination[0]
    y_axis = combination[1]

    plt.figure(figsize = (15, 8))

    sns.lmplot(x = x_axis, y = y_axis, hue = "diagnosis", data = df)

    plt.title(f"{x_axis} X {y_axis}")
    plt.show()
